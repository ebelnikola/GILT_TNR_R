# %% [markdown]
# Attempts to implement damped Newton method

# %%
using Pkg
Pkg.activate(".")
include("Tools.jl")
include("KrylovTechnical.jl")
include("GaugeFixing.jl");
include("./Lab/newton-step-SR.jl");
# Out:
#   Activating project at `~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R`
# GiltTNR/GiltTNR2D_essentials.py:113: SyntaxWarning: invalid escape sequence '\ '
#   """
# WARNING: using AbstractAlgebra.mul! in module Main conflicts with an existing identifier.
# GiltTNR/GiltTNR2D_essentials.py:113: SyntaxWarning: invalid escape sequence '\ '
#   """

# %% [markdown]
# Nikolay's two distance functions. Function embedded_distance will compute the distance between two tensors, even with different leg dimensions, by extending tensors by zeros. Function embedded_distance_with_additional_sign_fixing does the same, but additionally applies relative discrete gauge fixing. The code is suboptimal, but we need these functions only once in this computation.

# %%
function embedded_distance(tens1, tens2)
	if tens1.qhape != tens2.qhape
		throw("nonequal qhapes, code is not suited for such a situation.")
	end
	extended_shape = max.(tens1.shape, tens2.shape)
	tens1_ext = extend_blocks_by_zeros(tens1, extended_shape)
	tens2_ext = extend_blocks_by_zeros(tens2, extended_shape)
	tens1_ext - tens2_ext |> norm
end

function embedded_distance_with_additional_sign_fixing(tens1, tens2)
	if tens1.qhape != tens2.qhape
		throw("nonequal qhapes, code is not suited for such a situation.")
	end
	extended_shape = max.(tens1.shape, tens2.shape)
	tens1_ext = (extend_blocks_by_zeros(tens1, extended_shape) |> ju_to_py)
	tens2_ext = (extend_blocks_by_zeros(tens2, extended_shape) |> ju_to_py)
	tens2_f, tens2_accepted_elements, _ = fix_discrete_gauge(tens2_ext)
	tens1_f, _ = fix_discrete_gauge(tens1_ext, tens2_accepted_elements)
	tens1_f.to_ndarray() - tens2_f.to_ndarray() |> norm
end;

# %% [markdown]
# Now, we retrieve the trajectory corresponding to the found approximation of the critical temperature.

# %%
gilt_eps = 2e-5
chi = 20
cg_eps = 1e-10
gilt_pars = Dict(
	"gilt_eps" => gilt_eps,
	"cg_chis" => collect(1:chi),
	"cg_eps" => cg_eps,
	"verbosity" => 0,
	"rotate" => true,
)
Jratio = 1.0

relT=1.0
#do 4 steps from the critical tensor
initialA_pars = Dict("relT" => relT, "Jratio" => Jratio)
traj = trajectory(initialA_pars, 4, gilt_pars)["A"];
#NB traj consists of PyObjects

traj = traj .|> x -> fix_continuous_gauge(x)[1]; #this is still PyObjects
traj[5], accepted_elements, _ = fix_discrete_gauge(traj[5]; tol = 1e-7);

function fix_discrete_by_accepted_elements_if_possible(x)
	res = x
	try
		res = fix_discrete_gauge(x, accepted_elements)[1]
	catch
		res = fix_discrete_gauge(x)[1]
	end
	return res
end

traj = traj .|> x -> fix_discrete_by_accepted_elements_if_possible(x);
traj = py_to_ju.(traj);
traj = traj .|> x -> x / norm(x);

# %% [markdown]
# We fixed the gauge along the trajectory and normalize tensors. Note that it is not always possible to fix discrete gauge uniformly as at the beginning of the trajectory, the shape of the tensor changes. This may have caused some warnings, but it is fine.

# %% [markdown]
# We can now compute the distances. For the first ten tensors, we will use additional relative gauge fixing. We still will see warnings because of the changing shape of the tensor at the beginning of the trajectory. However, this does not introduce any issues, especially at the part of the trajectory close to the fixed point tensor.

# %%
distances = Float64[]
for i in 1:length(traj)-1
	if i <= 10
		push!(distances, embedded_distance_with_additional_sign_fixing(traj[i], traj[i+1]))
	else
		try
			push!(distances, embedded_distance(traj[i], traj[i+1]))
		catch
			push!(distances, NaN)
		end
	end
end

println(distances)
# Out:
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.08304572609637394 and became 0.0. Index CartesianIndex(1, 3, 4, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.08304572609637394 and became 0.0. Index CartesianIndex(3, 1, 1, 4)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.07230559786494163 and became 0.0. Index CartesianIndex(1, 3, 2, 3)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.07230559786494162 and became 0.0. Index CartesianIndex(3, 2, 3, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.03250010687211212 and became 0.0. Index CartesianIndex(1, 1, 10, 11)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.03250010687177233 and became 0.0. Index CartesianIndex(11, 10, 1, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.01887778539376026 and became 0.0. Index CartesianIndex(9, 1, 10, 3)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.018877785387950877 and became 0.0. Index CartesianIndex(3, 10, 1, 9)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.012069195516619904 and became 0.0. Index CartesianIndex(10, 1, 10, 4)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.01206919551415269 and became 0.0. Index CartesianIndex(4, 10, 1, 10)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.008651906251643065 and became 0.0. Index CartesianIndex(11, 1, 1, 13)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00865190625111384 and became 0.0. Index CartesianIndex(13, 1, 1, 11)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0071326006522108 and became 0.0. Index CartesianIndex(10, 9, 10, 12)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.007132600647988501 and became 0.0. Index CartesianIndex(12, 10, 9, 10)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.004728275117326775 and became 0.0. Index CartesianIndex(1, 9, 5, 9)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.004728275116243549 and became 0.0. Index CartesianIndex(9, 5, 9, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00190481130184242 and became 0.0. Index CartesianIndex(1, 1, 3, 6)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.001904811301615763 and became 0.0. Index CartesianIndex(6, 3, 1, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0017275121855206466 and became 0.0. Index CartesianIndex(9, 1, 3, 14)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0017275121852756677 and became 0.0. Index CartesianIndex(14, 3, 1, 9)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.001043514283855408 and became 0.0. Index CartesianIndex(1, 11, 7, 11)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0010435142834487343 and became 0.0. Index CartesianIndex(11, 7, 11, 1)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0005390447372605871 and became 0.0. Index CartesianIndex(15, 11, 1, 3)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0005390447370489915 and became 0.0. Index CartesianIndex(3, 1, 11, 15)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00022853184063498187 and became 0.0. Index CartesianIndex(16, 3, 1, 11)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00022853184059124973 and became 0.0. Index CartesianIndex(11, 1, 3, 16)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00020638897028706237 and became 0.0. Index CartesianIndex(8, 3, 1, 3)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0002063889702545349 and became 0.0. Index CartesianIndex(3, 1, 3, 8)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.010626308996882062 and became -2.2596526140269525e-13. Index CartesianIndex(15, 2, 11, 2)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.010587566981453298 and became -2.259229426227465e-13. Index CartesianIndex(2, 11, 2, 15)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was -0.000595911346608866 and became 0.0. Index CartesianIndex(9, 11, 1, 14)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0005887083989769249 and became 0.0. Index CartesianIndex(14, 1, 11, 9)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0005080288150444597 and became 0.0. Index CartesianIndex(19, 3, 1, 13)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was -0.0005022451181608181 and became 0.0. Index CartesianIndex(13, 1, 3, 19)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0004900699354909182 and became 0.0. Index CartesianIndex(20, 11, 1, 5)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.000480786163383584 and became 0.0. Index CartesianIndex(5, 1, 11, 20)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.00042068518396878553 and became 0.0. Index CartesianIndex(10, 3, 1, 3)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# ┌ Warning: new_list_of_elements: new entry is below the threshold. It was 0.0004137502024439715 and became 0.0. Index CartesianIndex(3, 1, 3, 10)
# └ @ Main ~/Personal/----Fisica----/_Projects/Fork/GILT_TNR_R/GaugeFixing.jl:466
# [0.4103425873634322, 0.2715652990604092, 0.18688932841620293, 0.057851774424087524]

# %%
function fix_discrete_gauge(A::Z2Tensor; tol = 1e-7)
    A1py, accepted_elements, _ = fix_discrete_gauge(ju_to_py(A); tol = tol)
    return py_to_ju(A1py), accepted_elements
end
# Out:
# fix_discrete_gauge (generic function with 5 methods)

# %%
A = Any[ NaN for _ in 1:40 ]; # list of tensors, Newton method trajectory
accepted_elements = Any[ NaN for _ in 1:40 ]; # list of elements in gauge-fixing
deltaA = Any[ NaN for _ in 1:40 ]; # list of deltaA's proposed by Newton method

# %%
A[1] = traj[4]
for i in 1:20
    A[i], accepted_elements[i] = fix_discrete_gauge(A[i]; tol = 1e-7);
    RA = gilt(A[i], accepted_elements[i], gilt_pars);
    println("i=",i) 
    println("||R(A[i])-A[i]||= ", embedded_distance(RA, A[i]))
    flush(stdout)
    #include("./Lab/newton-step-SR.jl");
    deltaA[i] = newton_correction(A[i], 5, accepted_elements[i], gilt_pars);
    println("||deltaA[i]||= ", norm(deltaA[i]))
    A[i+1] = A[i] + deltaA[i]
end
# Out:
# i=1
# ||R(A[i])-A[i]||= 0.05785177411987096
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (6.292097830712293e-39, 1.4634801511455341e-24, 2.8904106691199626e-24, 1.572920726968891e-16, 1.435798721981555e-16, 6.786399388193836e-13, 6.786399388193836e-13)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9863024519672752 + 0.0im
# -0.9355984375671192 + 0.0im
# -0.9247486902274563 + 0.0im
# 0.5557873651056882 + 0.0im
# 0.5499197267008445 + 0.0im
# 0.002439112988697585 + 0.402288303097577im
# 0.002439112988697585 - 0.402288303097577im
# ||deltaA[i]||= 0.12874516169461248
# i=2
# ||R(A[i])-A[i]||= 0.026995244880284538
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (1.476968423498486e-37, 1.2691521810100558e-22, 2.6038223219188768e-23, 2.3088274920924976e-17, 2.4581919991739477e-15, 3.3708678420468443e-15, 3.3708678420468443e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.988662980311041 + 0.0im
# -0.9727396894828838 + 0.0im
# -0.9618090918054824 + 0.0im
# 0.6334747129563162 + 0.0im
# 0.5790796833371918 + 0.0im
# -0.00405996171310414 + 0.5094534852434214im
# -0.00405996171310414 - 0.5094534852434214im
# ||deltaA[i]||= 0.06668245022810809
# i=3
# ||R(A[i])-A[i]||= 0.016216825763025234
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (9.612683115389573e-37, 4.073870332449609e-23, 5.0080171585055347e-23, 3.2422458019811067e-16, 3.2422458019811067e-16, 5.592907092260666e-16, 5.592907092260666e-16)
# └ *  number of operations = 44
# EIGENVALUES (INITIAL):
# 1.9923643791384449 + 0.0im
# -0.996797545234083 + 0.0im
# -0.99057419440573 + 0.0im
# 0.5996705598341938 + 0.02389494978662853im
# 0.5996705598341938 - 0.02389494978662853im
# 0.024878744835394664 + 0.5442312210130751im
# 0.024878744835394664 - 0.5442312210130751im
# ||deltaA[i]||= 0.01930678278865759
# i=4
# ||R(A[i])-A[i]||= 0.009531944594508016
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (1.0572932394282105e-34, 7.767530562321413e-22, 6.649503964784035e-22, 7.193858825188075e-18, 1.5667923025627804e-16, 7.449505048754135e-16, 7.449505048754135e-16)
# └ *  number of operations = 42
# EIGENVALUES (INITIAL):
# 1.9979530255149685 + 0.0im
# -1.0004557746465395 + 0.0im
# -0.9915531489985135 + 0.0im
# 0.6454895981505859 + 0.0im
# 0.601673885397119 + 0.0im
# 0.011843055476940586 + 0.551081384016101im
# 0.011843055476940586 - 0.551081384016101im
# ||deltaA[i]||= 0.020831898226206628
# i=5
# ||R(A[i])-A[i]||= 0.0028076287340797826
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (4.5477759312712114e-36, 7.786385645939495e-23, 2.2718775473162542e-22, 5.866433500769823e-19, 4.3723750042477887e-17, 5.323922231492706e-15, 5.323922231492706e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9977717338931007 + 0.0im
# -0.9953655471255693 + 0.0im
# -0.987418137059574 + 0.0im
# 0.6582079310022317 + 0.0im
# 0.5980728975313405 + 0.0im
# -0.010882416868012116 + 0.5086572487803527im
# -0.010882416868012116 - 0.5086572487803527im
# ||deltaA[i]||= 0.007203619297314357
# i=6
# ||R(A[i])-A[i]||= 0.001112343519357172
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  9 eigenvalues converged
# │ *  norm of residuals = (2.787293216621202e-37, 1.8306456705597068e-22, 1.1683807979809781e-22, 1.3788133069966052e-16, 9.545427840859751e-17, 9.545427840859751e-17, 8.957306520502476e-14, 8.957306520502476e-14, 2.926340155555757e-14)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.998237749923271 + 0.0im
# -0.9851113332261591 + 0.0im
# -0.9833824459811378 + 0.0im
# 0.5754308152432597 + 0.0im
# 0.00814411785375652 + 0.5308952947248466im
# 0.00814411785375652 - 0.5308952947248466im
# 0.455388223615651 + 0.1076324678305907im
# 0.455388223615651 - 0.1076324678305907im
# -0.44398420643646275 + 0.0im
# ||deltaA[i]||= 0.0012744236270746097
# i=7
# ||R(A[i])-A[i]||= 0.00032584262735926373
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (5.433335139375621e-36, 5.393747196906363e-23, 9.147486283797377e-22, 1.823664393828114e-16, 7.033470699749538e-16, 7.408697164375625e-15, 7.408697164375625e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9982678637092153 + 0.0im
# -0.9933663681126337 + 0.0im
# -0.9862024087713551 + 0.0im
# 0.5905914885839565 + 0.0im
# 0.5618931756884029 + 0.0im
# -0.00256060274854912 + 0.5208944730948877im
# -0.00256060274854912 - 0.5208944730948877im
# ||deltaA[i]||= 0.0004428697447083784
# i=8
# ||R(A[i])-A[i]||= 0.0001585223088585133
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  8 eigenvalues converged
# │ *  norm of residuals = (1.2085345520905278e-35, 3.1100559368588077e-22, 3.061161077451975e-22, 1.5733864674181874e-16, 2.5337839122925235e-14, 2.5337839122925235e-14, 4.197855705434059e-13, 4.197855705434059e-13)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9983685505387778 + 0.0im
# -0.9871718742171383 + 0.0im
# -0.9865075558645986 + 0.0im
# 0.5838745135135359 + 0.0im
# -0.00972393818420482 + 0.5045302565968368im
# -0.00972393818420482 - 0.5045302565968368im
# 0.3479233754658944 + 0.27322738886940146im
# 0.3479233754658944 - 0.27322738886940146im
# ||deltaA[i]||= 0.00014745752279778134
# i=9
# ||R(A[i])-A[i]||= 7.67458525121687e-5
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (2.595677035194202e-36, 8.366379006885573e-23, 4.102508709149225e-22, 2.622822363866209e-16, 2.622822363866209e-16, 1.8539637888368494e-15, 1.8539637888368494e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9983034099830117 + 0.0im
# -0.9932292986806736 + 0.0im
# -0.9859897006996525 + 0.0im
# 0.586106067152574 + 0.004067231594852839im
# 0.586106067152574 - 0.004067231594852839im
# -0.0034692529949879687 + 0.5196498167010337im
# -0.0034692529949879687 - 0.5196498167010337im
# ||deltaA[i]||= 0.00011076768916697248
# i=10
# ||R(A[i])-A[i]||= 3.7439968113860676e-5
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (2.4828331064885065e-36, 1.7827383139740067e-22, 5.491690290580858e-23, 2.3571920846142966e-16, 2.3571920846142966e-16, 7.444198072513103e-15, 7.444198072513103e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9982811103492986 + 0.0im
# -0.9933736664809788 + 0.0im
# -0.9860437269939327 + 0.0im
# 0.5878528509014215 + 0.004177067434814139im
# 0.5878528509014215 - 0.004177067434814139im
# -0.003741625577433675 + 0.5184040755706106im
# -0.003741625577433675 - 0.5184040755706106im
# ||deltaA[i]||= 5.8565132077374515e-5
# i=11
# ||R(A[i])-A[i]||= 2.5613088673596152e-5
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (3.151346150858167e-37, 5.309236576806893e-23, 7.020941655516807e-23, 1.111133252345109e-16, 1.111133252345109e-16, 1.3617307676906631e-15, 1.3617307676906631e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.998283947183767 + 0.0im
# -0.9934140518022755 + 0.0im
# -0.9860746491779011 + 0.0im
# 0.5879378835275364 + 0.004214553318527225im
# 0.5879378835275364 - 0.004214553318527225im
# -0.0037741169769061047 + 0.5182476307666251im
# -0.0037741169769061047 - 0.5182476307666251im
# ||deltaA[i]||= 4.053689815032226e-5
# i=12
# ||R(A[i])-A[i]||= 8.60080065022117e-6
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (6.67871372940144e-36, 8.731218012506302e-23, 9.356326641729845e-22, 7.084473570752672e-19, 2.3513285232914266e-14, 1.124406692858487e-14, 1.124406692858487e-14)
# └ *  number of operations = 42
# EIGENVALUES (INITIAL):
# 1.9981641213131156 + 0.0im
# -0.9979011933256217 + 0.0im
# -0.9860648351715553 + 0.0im
# 0.7097401328157705 + 0.0im
# 0.5564184303134666 + 0.0im
# -0.025945385273402316 + 0.5192958474133038im
# -0.025945385273402316 - 0.5192958474133038im
# ||deltaA[i]||= 1.7835374522877884e-5
# i=13
# ||R(A[i])-A[i]||= 4.081715484105463e-6
# ┌ Info: Arnoldi eigsolve finished after 2 iterations:
# │ *  5 eigenvalues converged
# │ *  norm of residuals = (1.5264273612158802e-28, 3.372611436217093e-17, 5.2778189831816646e-17, 1.247006959319335e-13, 1.247006959319335e-13)
# └ *  number of operations = 35
# EIGENVALUES (INITIAL):
# 1.9982943428748612 + 0.0im
# -0.9926739924586647 + 0.0im
# -0.9860892508425791 + 0.0im
# 0.6008572116170191 + 0.07307614344426298im
# 0.6008572116170191 - 0.07307614344426298im
# ||deltaA[i]||= 6.686143258980363e-6
# i=14
# ||R(A[i])-A[i]||= 1.8219672123068455e-6
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (7.311869429755221e-36, 1.157172246974318e-22, 6.267888825428443e-23, 5.31656985320097e-16, 5.31656985320097e-16, 3.906085635523513e-15, 3.906085635523513e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9982878358569949 + 0.0im
# -0.9934843135779109 + 0.0im
# -0.9860573524689005 + 0.0im
# 0.5880307912880767 + 0.012024399665305172im
# 0.5880307912880767 - 0.012024399665305172im
# -0.003902242363876671 + 0.5186556799636284im
# -0.003902242363876671 - 0.5186556799636284im
# ||deltaA[i]||= 2.263874832408785e-6
# i=15
# ||R(A[i])-A[i]||= 1.1883032370756234e-6
# ┌ Info: Arnoldi eigsolve finished after 2 iterations:
# │ *  5 eigenvalues converged
# │ *  norm of residuals = (1.1057428062423285e-26, 1.7305701093013953e-16, 6.435745807270806e-16, 3.3150627746078855e-13, 3.3150627746078855e-13)
# └ *  number of operations = 34
# EIGENVALUES (INITIAL):
# 1.9983264419745996 + 0.0im
# -0.992733369778718 + 0.0im
# -0.9860546162177019 + 0.0im
# 0.6132462370834858 + 0.051724487006467416im
# 0.6132462370834858 - 0.051724487006467416im
# ||deltaA[i]||= 1.5882289461511637e-6
# i=16
# ||R(A[i])-A[i]||= 4.815834499355488e-7
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (1.3458855347719579e-37, 3.8742528386775474e-23, 2.130735768437281e-22, 4.707939869007696e-17, 4.707939869007696e-17, 2.3925779120984488e-15, 2.3925779120984488e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9982860275887566 + 0.0im
# -0.9933525889894117 + 0.0im
# -0.986055111547352 + 0.0im
# 0.5869958471196186 + 0.004112412148389465im
# 0.5869958471196186 - 0.004112412148389465im
# -0.0036140473963739567 + 0.5187426217166979im
# -0.0036140473963739567 - 0.5187426217166979im
# ||deltaA[i]||= 7.037427504409615e-7
# i=17
# ||R(A[i])-A[i]||= 2.9054134050554436e-7
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (4.995026250117216e-38, 2.677272439893439e-23, 3.088484751612466e-24, 1.524157114924052e-16, 1.524157114924052e-16, 5.091036588604049e-16, 5.091036588604049e-16)
# └ *  number of operations = 44
# EIGENVALUES (INITIAL):
# 1.9982872951858313 + 0.0im
# -0.9933542998253941 + 0.0im
# -0.9860549993317748 + 0.0im
# 0.5870549097639813 + 0.004114785251865058im
# 0.5870549097639813 - 0.004114785251865058im
# -0.00359670415950711 + 0.5187494093173063im
# -0.00359670415950711 - 0.5187494093173063im
# ||deltaA[i]||= 3.515464899489413e-7
# i=18
# ||R(A[i])-A[i]||= 1.2978430641492236e-7
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (3.517477769961798e-36, 8.1285217271464e-23, 1.8898083271818603e-22, 1.7906595467259557e-18, 5.356340428687925e-16, 2.5604966718407378e-15, 2.5604966718407378e-15)
# └ *  number of operations = 42
# EIGENVALUES (INITIAL):
# 1.9985005725745972 + 0.0im
# -0.997614788633846 + 0.0im
# -0.9859860831569333 + 0.0im
# 0.6590185167905847 + 0.0im
# 0.5734791913822763 + 0.0im
# -0.030174545491511908 + 0.5188232288969469im
# -0.030174545491511908 - 0.5188232288969469im
# ||deltaA[i]||= 2.3034601269785767e-7
# i=19
# ||R(A[i])-A[i]||= 7.408029749614847e-8
# ┌ Info: Arnoldi eigsolve finished after 3 iterations:
# │ *  7 eigenvalues converged
# │ *  norm of residuals = (1.8315508335914405e-36, 1.336791305841467e-21, 9.201513676089281e-23, 2.982321626572294e-16, 2.982321626572294e-16, 2.8803355507062524e-15, 2.8803355507062524e-15)
# └ *  number of operations = 43
# EIGENVALUES (INITIAL):
# 1.9982882307421752 + 0.0im
# -0.993353948254955 + 0.0im
# -0.9860553598969548 + 0.0im
# 0.5871072615860197 + 0.003626564042732989im
# 0.5871072615860197 - 0.003626564042732989im
# -0.0035651931784298607 + 0.5187180880874247im
# -0.0035651931784298607 - 0.5187180880874247im
# ||deltaA[i]||= 9.734895414461527e-8
# i=20
# ||R(A[i])-A[i]||= 3.2114275017823165e-8
# ┌ Info: Arnoldi eigsolve finished after 2 iterations:
# │ *  5 eigenvalues converged
# │ *  norm of residuals = (4.567538958943529e-29, 1.0947738258876279e-17, 2.2776765369336122e-17, 4.291580068145838e-13, 4.291580068145838e-13)
# └ *  number of operations = 35
# EIGENVALUES (INITIAL):
# 1.998286617293725 + 0.0im
# -0.9933495138119328 + 0.0im
# -0.9860552089802954 + 0.0im
# 0.5870316079588531 + 0.003404166360323306im
# 0.5870316079588531 - 0.003404166360323306im
# ||deltaA[i]||= 5.046649188278065e-8

# %%
# test
include("./Lab/newton-step-SR.jl");
deltaA1 = newton_correction(A[1], 5, accepted_elements[1], gilt_pars);
# Out:
# GiltTNR/GiltTNR2D_essentials.py:113: SyntaxWarning: invalid escape sequence '\ '
#   """
# ┌ Info: Arnoldi eigsolve finished after 2 iterations:
# │ *  5 eigenvalues converged
# │ *  norm of residuals = (3.027495963983217e-35, 1.603330423275423e-22, 8.055802593474995e-23, 2.9487220642280986e-14, 4.699351098300212e-13)
# └ *  number of operations = 34
# EIGENVALUES (INITIAL):
# 1.9870691501489048 + 0.0im
# -0.9162160360072799 + 0.0im
# -0.9034101124751837 + 0.0im
# 0.4422878554999291 + 0.0im
# -0.3363884937530674 + 0.0im
